# %%
from DegScore import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from arnie.mfe import mfe

# %%
package = "eternafold"
linear=True

seq = "ACAUGCUAGCUAAUCGCUAGU"
ss = mfe(seq, package=package, linear=linear, viterbi=True)
bprna_string = write_loop_assignments(ss)
encoding = encode_input(seq, bprna_string)
e
# Out:
# (21, 250)

# %%
df
# Out:
#      Unnamed: 0                   ID  Accept  \
# 0             0                    R       1
# 1             1                  R.2       1
# 2             2                  R.3       1
# 3             3                  R.4       1
# 4             4                R.3.2       1
# ..          ...                  ...     ...
# 110         110    R.3.2.2.3.3.3.3.2       1
# 111         111    R.3.2.2.3.3.2.2.4       1
# 112         112    R.3.2.2.3.3.2.3.4       1
# 113         113  R.3.2.2.3.3.2.3.4.4       1
# 114         114  R.3.2.2.3.3.2.3.4.2       1
#
#                                                 frag_1 segment_1  \
# 0    AUGGGCGGGUCCGGCGGAAGUGGGUAUCAACCAUACCGGGUUGUAG...         G
# 1    AUGGGCGGGUCCGGCGGAAGUGGGUAUCAACCAUACCGGGUUGUAG...         G
# 2    AUGGGCGGGUCCGGCGGAAGUGGGUAUCAACCAUACCGGGUUGUAG...         G
# 3    AUGGGCGGGUCCGGCGGAAGUGGGUAUCAACCGUACCGGGUUGUAG...         G
# 4    AUGGGCGGGUCCGGCGGAAGUGGGUAUCAACCAUACCGGGUUGUAG...         G
# ...

# %%
df = pd.read_csv('output/MEV_min_bpunpaired.MCTS_best.20210212-152802.txt',delimiter='\t')

# %%
df
# Out:
#    Unnamed: 0                 ID  Accept  \
# 0           0  R.3.2.2.3.3.2.3.4       1
#
#                                               frag_1 segment_1  \
# 0  AUGGGCGGCUCCGGUGGAAGUGGGUAUCAACCAUACCGGGUUGUAG...         G
#
#    binary_constraint_1_1  float_constraint_1_1  raw_value_1         move
# 0                      0              0.442227     0.557773  (1)Mutate:G
